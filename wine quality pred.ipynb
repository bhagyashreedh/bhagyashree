# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("wineQT.csv")

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
#droping the id column as not required for the prediction
df= df.drop('Id', axis=1)

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
df.shape
# Out:
# (1143, 12)

# %%
# checking the datattypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 107.3 KB

# %%
# numbers of rows and column in the dataset
df.shape
# Out:
# (1143, 12)

# %%
# find the null values present in the dataset
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# ### no null values are present in the dataset

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %%
# finding the correlation between features
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.250728     0.673157
# volatile acidity          -0.250728          1.000000    -0.544187
# citric acid                0.673157         -0.544187     1.000000
# residual sugar             0.171831         -0.005751     0.175815
# chlorides                  0.107889          0.056336     0.245312
# free sulfur dioxide       -0.164831         -0.001962    -0.057589
# total sulfur dioxide      -0.110628          0.077748     0.036871
# density                    0.681501          0.016512     0.375243
# pH                        -0.685163          0.221492    -0.546339
# sulphates                  0.174592         -0.276079     0.331232
# alcohol                   -0.075055         -0.203909     0.106250
# quality                    0.121970         -0.407394     0.240821
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
# finding the datatypes in features
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 107.3 KB

# %%
df.quality.value_counts()
# Out:
# 5    483
# 6    462
# 7    143
# 4     33
# 8     16
# 3      6
# Name: quality, dtype: int64

# %%
sns.pairplot(df)

# %% [markdown]
# ### exploratory data analysis

# %%
df['pH'].round().value_counts()
sns.barplot(x=df['pH'].round().value_counts(),y=df['quality'],data=df)
# Out:
# <AxesSubplot:xlabel='pH', ylabel='quality'>

# %%
df['citric acid'].round().value_counts()
sns.barplot(x=df['citric acid'].round().value_counts(),y=df['quality'],data=df)
# Out:
# <AxesSubplot:xlabel='citric acid', ylabel='quality'>

# %%
df['residual sugar'].round().value_counts()
sns.barplot(x=df['residual sugar'].round().value_counts(),y=df['quality'],data=df)
# Out:
# <AxesSubplot:xlabel='residual sugar', ylabel='quality'>

# %%
df['chlorides'].round().value_counts()
sns.barplot(x=df['chlorides'].round().value_counts(),y=df['quality'],data=df)
# Out:
# <AxesSubplot:xlabel='chlorides', ylabel='quality'>

# %%
df['free sulfur dioxide'].round().value_counts()
sns.barplot(x=df['free sulfur dioxide'].round().value_counts(),y=df['quality'],data=df)
# Out:
# <AxesSubplot:xlabel='free sulfur dioxide', ylabel='quality'>

# %%
df['total sulfur dioxide'].round().value_counts()
sns.barplot(x=df['total sulfur dioxide'].round().value_counts(),y=df['quality'],data=df)
# Out:
# <AxesSubplot:xlabel='total sulfur dioxide', ylabel='quality'>

# %%
df['density'].round().value_counts()
sns.barplot(x=df['density'].round().value_counts(),y=df['quality'],data=df)
# Out:
# <AxesSubplot:xlabel='density', ylabel='quality'>

# %%
df['sulphates'].round().value_counts()
sns.barplot(x=df['sulphates'].round().value_counts(),y=df['quality'],data=df)
# Out:
# <AxesSubplot:xlabel='sulphates', ylabel='quality'>

# %%
df['alcohol'].round().value_counts()
sns.barplot(x=df['alcohol'].round().value_counts(),y=df['quality'],data=df)
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='quality'>

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
x.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol
# 0      9.4
# 1      9.8
# 2      9.8
# 3      9.8
# 4      9.4

# %%
y.head()
# Out:
# 0    5
# 1    5
# 2    5
# 3    6
# 4    5
# Name: quality, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
x_train=scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
x_train
# Out:
# array([[ 2.86436173, -0.83577596, -0.21736842, ...,  1.243708  ,
#          0.03230348, -0.82649676],
#        [-1.53499184,  0.12399529, -0.94809595, ..., -0.10408128,
#          1.40890311,  1.12541288],
#        [-0.43515345, -0.83577596, -0.69756079, ..., -0.68170525,
#         -0.40417933,  1.18666527],
#        ...,
#        [-0.43515345, -1.47562347, -1.03160766, ..., -0.33940956,
#         -1.27714495,  1.17237305],
#        [-1.53499184, -1.47562347, -1.28214281, ..., -0.68170525,
#         -2.35156417,  1.22035409],
#        [-1.53499184, -1.47562347, -0.67668287, ...,  0.66608402,
#         -1.37787175, -0.82649676]])

# %%
y_train
# Out:
# 2194    175000.000000
# 958     387000.000000
# 1533    264000.000000
# 654     723000.000000
# 1497    157500.000000
#             ...
# 4426    282508.888889
# 466     875000.000000
# 3092    290000.000000
# 3772    600000.000000
# 860     475000.000000
# Name: price, Length: 3220, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
regression=LinearRegression()
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(regression.coef_)
# Out:
# [ 4.42109900e-02 -1.34670790e+00 -3.14932885e-01 -2.68489475e-03
#  -1.87846120e+00  2.37296538e-03 -2.77800524e-03 -1.60760914e+01
#  -2.85153430e-01  9.58575428e-01  2.74942710e-01]

# %%
print(regression.intercept_)
23.01581920903955
regression.get_params()
# Out:
# 19.808325962059165
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'normalize': False}

# %%
variable=regression.predict(x_test)
variable
# Out:
# array([5.36000297, 4.79492333, 5.21981749, 5.06895199, 6.13445095,
#        6.57189917, 5.34817328, 5.05662328, 5.77534543, 5.32547538,
#        6.31826978, 6.38106189, 5.29818534, 6.18557618, 5.84192953,
#        4.82924975, 5.70788286, 5.70507514, 5.48025405, 6.38644596,
#        6.07503834, 6.03756363, 5.12803998, 6.50008965, 5.60225673,
#        5.08826075, 6.54588252, 5.98482242, 5.08282091, 5.56014048,
#        6.16152684, 5.47623828, 6.61340125, 5.73784823, 5.56133374,
#        5.21671314, 5.50782597, 6.05642379, 6.89926477, 6.54409128,
#        6.4532601 , 5.35314579, 6.98669792, 5.36530932, 5.05923246,
#        5.04845307, 5.60012044, 5.88783391, 4.58613246, 5.67995569,
#        6.40956797, 5.23872591, 5.59694087, 5.87660394, 5.76942875,
#        6.40512955, 5.50867909, 5.69868908, 6.04177149, 5.23066525,
#        5.54559863, 5.94098249, 5.62428238, 6.35083107, 6.14721924,
#        5.37162544, 6.85591274, 5.24335548, 4.82122589, 6.01076048,
# ...

# %%
plt.scatter(y_test,variable)

# %%
b=(y_test-variable)
plt.scatter(variable,b)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
print(mean_absolute_error(y_test,variable))
print(mean_squared_error(y_test,variable))
print(np.sqrt(mean_squared_error(y_test,variable)))
# Out:
# 0.480174742486661
# 0.38559178373841735
# 0.6209603721159808

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,variable)
score
# Out:
# 0.33681527739545847

# %%
1-(1-score)*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1)
# Out:
# 0.3147759059493861
